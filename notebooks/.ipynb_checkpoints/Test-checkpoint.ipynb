# %% [markdown]
# ## Test post
#
# There are some equations
#
# $
# \sum_k x_k
# $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.normal(0,1,100)

# %%
plt.plot(x)
plt.show()
